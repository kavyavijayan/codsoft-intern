# %%
contacts = []

def add_contact():
    name = input("Enter name: ")
    phone = input("Enter phone number: ")
    email = input("Enter email: ")
    address = input("Enter address: ")
    contact = {
        'name': name,
        'phone': phone,
        'email': email,
        'address': address
    }
    contacts.append(contact)
    print("Contact added successfully!")

def view_contacts():
    if not contacts:
        print("No contacts found.")
    else:
        for contact in contacts:
            print(f"{contact['name']} - {contact['phone']}")

def search_contact():
    query = input("Enter name or phone number to search: ")
    for contact in contacts:
        if query in contact['name'] or query in contact['phone']:
            print(contact)
            return
    print("No contact found.")

def update_contact():
    query = input("Enter name or phone number to update: ")
    for contact in contacts:
        if query in contact['name'] or query in contact['phone']:
            contact['name'] = input("Enter new name: ") or contact['name']
            contact['phone'] = input("Enter new phone number: ") or contact['phone']
            contact['email'] = input("Enter new email: ") or contact['email']
            contact['address'] = input("Enter new address: ") or contact['address']
            print("Contact updated successfully!")
            return
    print("No contact found.")

def delete_contact():
    query = input("Enter name or phone number to delete: ")
    for contact in contacts:
        if query in contact['name'] or query in contact['phone']:
            contacts.remove(contact)
            print("Contact deleted successfully!")
            return
    print("No contact found.")

def main():
    while True:
        print("\n1. Add Contact\n2. View Contacts\n3. Search Contact\n4. Update Contact\n5. Delete Contact\n6. Exit")
        choice = input("Choose an option: ")
        if choice == '1':
            add_contact()
        elif choice == '2':
            view_contacts()
        elif choice == '3':
            search_contact()
        elif choice == '4':
            update_contact()
        elif choice == '5':
            delete_contact()
        elif choice == '6':
            break
        else:
            print("Invalid choice. Please try again.")

if __name__ == "__main__":
    main()
# Out:
# 1. Add Contact
# 2. View Contacts
# 3. Search Contact
# 4. Update Contact
# 5. Delete Contact
# 6. Exit
# Choose an option: 1
# Enter name: abc
# Enter phone number: 1234
# Enter email: dfgh
# Enter address: jhfkjhkjkf,n
# Contact added successfully!
#
# 1. Add Contact
# 2. View Contacts
# 3. Search Contact
# 4. Update Contact
# 5. Delete Contact
# 6. Exit
# Choose an option: 1
# Enter name: def
# Enter phone number: 3456
# Enter email: dgfjk
# Enter address: jhfuefh
# Contact added successfully!
#
# 1. Add Contact
# 2. View Contacts
# 3. Search Contact
# 4. Update Contact
# 5. Delete Contact
# 6. Exit
# Choose an option: 2
# abc - 1234
# def - 3456
#
# 1. Add Contact
# 2. View Contacts
# 3. Search Contact
# 4. Update Contact
# 5. Delete Contact
# 6. Exit
# Choose an option: 2
# abc - 1234
# def - 3456
#
# 1. Add Contact
# 2. View Contacts
# 3. Search Contact
# 4. Update Contact
# 5. Delete Contact
# 6. Exit
# Choose an option: 3
# Enter name or phone number to search: def
# {'name': 'def', 'phone': '3456', 'email': 'dgfjk', 'address': 'jhfuefh'}
#
# 1. Add Contact
# 2. View Contacts
# 3. Search Contact
# 4. Update Contact
# 5. Delete Contact
# 6. Exit
